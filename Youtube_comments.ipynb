# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 googleapiclient pandas
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement googleapiclient (from versions: none)
# ERROR: No matching distribution found for googleapiclient

# %%
import time
from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# # **BIHAR**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["rI78pAffkos", "RoGnlXQuJpk", "5Rc_Ka0AuSk", "clguUra-8QI", "bg4urpy-6LY"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_bihar.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_bihar.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: rI78pAffkos
# ✅ Fetched 100 comments so far for rI78pAffkos...
# ✅ Fetched 200 comments so far for rI78pAffkos...
# ✅ Fetched 300 comments so far for rI78pAffkos...
# ✅ Fetched 400 comments so far for rI78pAffkos...
# ✅ Fetched 500 comments so far for rI78pAffkos...
# ✅ Fetched 600 comments so far for rI78pAffkos...
# ✅ Fetched 700 comments so far for rI78pAffkos...
# ✅ Fetched 800 comments so far for rI78pAffkos...
# ✅ Fetched 900 comments so far for rI78pAffkos...
# ✅ Fetched 1000 comments so far for rI78pAffkos...
# ✅ Fetched 1100 comments so far for rI78pAffkos...
# ✅ Fetched 1200 comments so far for rI78pAffkos...
# ✅ Fetched 1300 comments so far for rI78pAffkos...
# ✅ Fetched 1400 comments so far for rI78pAffkos...
# ✅ Fetched 1500 comments so far for rI78pAffkos...
# ✅ Fetched 1600 comments so far for rI78pAffkos...
# ✅ Fetched 1700 comments so far for rI78pAffkos...
# ✅ Fetched 1800 comments so far for rI78pAffkos...
# ...

# %% [markdown]
# # **MAHARASTRA**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["rI78pAffkos", "RoGnlXQuJpk", "5Rc_Ka0AuSk", "clguUra-8QI", "bg4urpy-6LY"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_bihar.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_bihar.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: rI78pAffkos
# ✅ Fetched 100 comments so far for rI78pAffkos...
# ✅ Fetched 200 comments so far for rI78pAffkos...
# ✅ Fetched 300 comments so far for rI78pAffkos...
# ✅ Fetched 400 comments so far for rI78pAffkos...
# ✅ Fetched 500 comments so far for rI78pAffkos...
# ✅ Fetched 600 comments so far for rI78pAffkos...
# ✅ Fetched 700 comments so far for rI78pAffkos...
# ✅ Fetched 800 comments so far for rI78pAffkos...
# ✅ Fetched 900 comments so far for rI78pAffkos...
# ✅ Fetched 1000 comments so far for rI78pAffkos...
# ✅ Fetched 1100 comments so far for rI78pAffkos...
# ✅ Fetched 1200 comments so far for rI78pAffkos...
# ✅ Fetched 1300 comments so far for rI78pAffkos...
# ✅ Fetched 1400 comments so far for rI78pAffkos...
# ✅ Fetched 1500 comments so far for rI78pAffkos...
# ✅ Fetched 1600 comments so far for rI78pAffkos...
# ✅ Fetched 1700 comments so far for rI78pAffkos...
# ✅ Fetched 1800 comments so far for rI78pAffkos...
# ...

# %% [markdown]
# # **UTTAR PRADESH**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,
                pageToken=next_page_token
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")
            time.sleep(1)  # Sleep to avoid API rate limits

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["qC8SlZL2_Fs","zZ9HAMU7saw","rhljqLzZpz8","zzuYN-KW0nk","W4ZWzMzgrg0"]

# Fetch comments for multiple videos
all_comments = []
batch_size = 5

for i in range(0, len(video_ids), batch_size):
    batch = video_ids[i:i+batch_size]
    for video_id in batch:
        print(f"🚀 Fetching comments for video: {video_id}")
        comments_data = get_all_youtube_comments(video_id)
        all_comments.extend(comments_data)

    # ✅ Sleep after processing a batch to avoid hitting the API rate limit
    print("⏳ Waiting 10 seconds before processing the next batch...")
    time.sleep(10)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_large_comments_uttarpradesh.csv", index=False)
    print("✅ All comments saved to 'youtube_large_comments_uttarpradesh.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: qC8SlZL2_Fs
# ✅ Fetched 100 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 200 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 300 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 400 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 500 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 600 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 700 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 800 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 900 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1000 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1100 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1200 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1300 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1400 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1500 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1600 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1700 comments so far for qC8SlZL2_Fs...
# ✅ Fetched 1800 comments so far for qC8SlZL2_Fs...
# ...

# %% [markdown]
# # **PUNJAB**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["rhgG1XrY8c0", "H1w6iI-owo4","yv9rypQVnwI","idY1JHHP-bI","uTfNHX08dxc","sWc1xg7TvSw","P7MQbIE2f-s"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_punjab.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_punjab.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: rhgG1XrY8c0
# ✅ Fetched 100 comments so far for rhgG1XrY8c0...
# ✅ Successfully fetched 117 total comments for rhgG1XrY8c0
# 🚀 Fetching comments for video: H1w6iI-owo4
# ✅ Fetched 100 comments so far for H1w6iI-owo4...
# ✅ Fetched 200 comments so far for H1w6iI-owo4...
# ✅ Fetched 300 comments so far for H1w6iI-owo4...
# ✅ Fetched 400 comments so far for H1w6iI-owo4...
# ✅ Fetched 500 comments so far for H1w6iI-owo4...
# ✅ Fetched 600 comments so far for H1w6iI-owo4...
# ✅ Fetched 700 comments so far for H1w6iI-owo4...
# ✅ Fetched 800 comments so far for H1w6iI-owo4...
# ✅ Fetched 900 comments so far for H1w6iI-owo4...
# ✅ Fetched 1000 comments so far for H1w6iI-owo4...
# ✅ Fetched 1100 comments so far for H1w6iI-owo4...
# ✅ Fetched 1200 comments so far for H1w6iI-owo4...
# ✅ Fetched 1300 comments so far for H1w6iI-owo4...
# ✅ Fetched 1400 comments so far for H1w6iI-owo4...
# ✅ Fetched 1500 comments so far for H1w6iI-owo4...
# ...

# %% [markdown]
# # **RAJASTHAN**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["XDB7hqIR9SA","dAxIDmpsfns","jGQyh2hFMmQ","LokfM_pw96I"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_rajasthan.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_rajasthan.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: XDB7hqIR9SA
# ✅ Fetched 100 comments so far for XDB7hqIR9SA...
# ✅ Fetched 200 comments so far for XDB7hqIR9SA...
# ✅ Fetched 300 comments so far for XDB7hqIR9SA...
# ✅ Fetched 400 comments so far for XDB7hqIR9SA...
# ✅ Fetched 500 comments so far for XDB7hqIR9SA...
# ✅ Fetched 600 comments so far for XDB7hqIR9SA...
# ✅ Successfully fetched 658 total comments for XDB7hqIR9SA
# 🚀 Fetching comments for video: dAxIDmpsfns
# ✅ Fetched 100 comments so far for dAxIDmpsfns...
# ✅ Successfully fetched 104 total comments for dAxIDmpsfns
# 🚀 Fetching comments for video: jGQyh2hFMmQ
# ✅ Fetched 100 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 200 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 300 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 400 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 500 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 600 comments so far for jGQyh2hFMmQ...
# ✅ Fetched 700 comments so far for jGQyh2hFMmQ...
# ...

# %% [markdown]
# ## **GUJURAT**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["K78RcIK7sdw","EdWw3zzRel0","1gYtLcW2GhI","yYCUOXsKth4","x4pnS6dqJqc","897tTLg5JBE","_pO6_IJkmMw","zIvfX9vc0Nw"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_gujarat.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_gujarat.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: K78RcIK7sdw
# ✅ Fetched 100 comments so far for K78RcIK7sdw...
# ✅ Fetched 200 comments so far for K78RcIK7sdw...
# ✅ Fetched 300 comments so far for K78RcIK7sdw...
# ✅ Successfully fetched 310 total comments for K78RcIK7sdw
# 🚀 Fetching comments for video: EdWw3zzRel0
# ✅ Fetched 100 comments so far for EdWw3zzRel0...
# ✅ Fetched 200 comments so far for EdWw3zzRel0...
# ✅ Fetched 300 comments so far for EdWw3zzRel0...
# ✅ Fetched 400 comments so far for EdWw3zzRel0...
# ✅ Fetched 500 comments so far for EdWw3zzRel0...
# ✅ Fetched 600 comments so far for EdWw3zzRel0...
# ✅ Fetched 700 comments so far for EdWw3zzRel0...
# ✅ Fetched 800 comments so far for EdWw3zzRel0...
# ✅ Fetched 900 comments so far for EdWw3zzRel0...
# ✅ Fetched 1000 comments so far for EdWw3zzRel0...
# ✅ Fetched 1100 comments so far for EdWw3zzRel0...
# ✅ Fetched 1200 comments so far for EdWw3zzRel0...
# ✅ Fetched 1300 comments so far for EdWw3zzRel0...
# ...

# %% [markdown]
# # **West Bengal**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["DLivdGNlEFo","r9sAlTCXcYA","J1rKle2qrSk","wUJAJVeUhKo","TPXXlZ1GFQw","h8m8Myt-HYQ"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_westbengal.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_westbengal.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: DLivdGNlEFo
# ✅ Fetched 100 comments so far for DLivdGNlEFo...
# ✅ Fetched 200 comments so far for DLivdGNlEFo...
# ✅ Fetched 300 comments so far for DLivdGNlEFo...
# ✅ Fetched 400 comments so far for DLivdGNlEFo...
# ✅ Fetched 500 comments so far for DLivdGNlEFo...
# ✅ Fetched 600 comments so far for DLivdGNlEFo...
# ✅ Fetched 700 comments so far for DLivdGNlEFo...
# ✅ Fetched 800 comments so far for DLivdGNlEFo...
# ✅ Fetched 900 comments so far for DLivdGNlEFo...
# ✅ Fetched 1000 comments so far for DLivdGNlEFo...
# ✅ Fetched 1100 comments so far for DLivdGNlEFo...
# ✅ Fetched 1200 comments so far for DLivdGNlEFo...
# ✅ Fetched 1300 comments so far for DLivdGNlEFo...
# ✅ Fetched 1400 comments so far for DLivdGNlEFo...
# ✅ Fetched 1500 comments so far for DLivdGNlEFo...
# ✅ Fetched 1600 comments so far for DLivdGNlEFo...
# ✅ Fetched 1700 comments so far for DLivdGNlEFo...
# ✅ Fetched 1800 comments so far for DLivdGNlEFo...
# ...

# %% [markdown]
# # **Odisha**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["3Lkrn0GOuvQ","npH76g4cdHE","OfDhtOTxNMY","g2V7IpQd-kU"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_odisha.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_odisha.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: 3Lkrn0GOuvQ
# ✅ Fetched 100 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 200 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 300 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 400 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 500 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 600 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 700 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 800 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 900 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1000 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1100 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1200 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1300 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1400 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1500 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1600 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1700 comments so far for 3Lkrn0GOuvQ...
# ✅ Fetched 1800 comments so far for 3Lkrn0GOuvQ...
# ...

# %% [markdown]
# # **JHARKHAND**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["arqJGIhvTFc","6pt4UzhPxhs","uckq_1NnEyw","7VAveax4A0g"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_jharkhand.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_jharkhand.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: arqJGIhvTFc
# ✅ Successfully fetched 93 total comments for arqJGIhvTFc
# 🚀 Fetching comments for video: 6pt4UzhPxhs
# ✅ Fetched 100 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 200 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 300 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 400 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 500 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 600 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 700 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 800 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 900 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1000 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1100 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1200 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1300 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1400 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1500 comments so far for 6pt4UzhPxhs...
# ✅ Fetched 1600 comments so far for 6pt4UzhPxhs...
# ...

# %% [markdown]
# # **CHHATTISGARH**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["2sv5cP77CEw","zvjnbqWhJ9s","cB7s7jh9HFc"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_chhattisgarh.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_chhattisgarh.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: 2sv5cP77CEw
# ✅ Fetched 100 comments so far for 2sv5cP77CEw...
# ✅ Fetched 200 comments so far for 2sv5cP77CEw...
# ✅ Fetched 300 comments so far for 2sv5cP77CEw...
# ✅ Fetched 400 comments so far for 2sv5cP77CEw...
# ✅ Fetched 500 comments so far for 2sv5cP77CEw...
# ✅ Fetched 600 comments so far for 2sv5cP77CEw...
# ✅ Fetched 700 comments so far for 2sv5cP77CEw...
# ✅ Fetched 800 comments so far for 2sv5cP77CEw...
# ✅ Fetched 900 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1000 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1100 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1200 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1300 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1400 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1500 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1600 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1700 comments so far for 2sv5cP77CEw...
# ✅ Fetched 1800 comments so far for 2sv5cP77CEw...
# ...

# %% [markdown]
# # **UTTARAKHAND**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["UJ17k2_IImw","2-ueywULFNc","5a-M-wtVP2g","SkqrvRyvlk0","Z1Omjei_JHM"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_uttrakhand.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_uttrakhand.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: UJ17k2_IImw
# ✅ Fetched 100 comments so far for UJ17k2_IImw...
# ✅ Fetched 200 comments so far for UJ17k2_IImw...
# ✅ Fetched 300 comments so far for UJ17k2_IImw...
# ✅ Fetched 400 comments so far for UJ17k2_IImw...
# ✅ Fetched 500 comments so far for UJ17k2_IImw...
# ✅ Fetched 600 comments so far for UJ17k2_IImw...
# ✅ Fetched 700 comments so far for UJ17k2_IImw...
# ✅ Fetched 800 comments so far for UJ17k2_IImw...
# ✅ Fetched 900 comments so far for UJ17k2_IImw...
# ✅ Fetched 1000 comments so far for UJ17k2_IImw...
# ✅ Fetched 1100 comments so far for UJ17k2_IImw...
# ✅ Fetched 1200 comments so far for UJ17k2_IImw...
# ✅ Fetched 1300 comments so far for UJ17k2_IImw...
# ✅ Successfully fetched 1372 total comments for UJ17k2_IImw
# 🚀 Fetching comments for video: 2-ueywULFNc
# ✅ Fetched 100 comments so far for 2-ueywULFNc...
# ✅ Fetched 200 comments so far for 2-ueywULFNc...
# ✅ Fetched 300 comments so far for 2-ueywULFNc...
# ...

# %% [markdown]
# # **HIMACHAL PRADESH**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["zNXDFR6Mxvw"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_himachak.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_himachal.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: zNXDFR6Mxvw
# ✅ Successfully fetched 48 total comments for zNXDFR6Mxvw
# ✅ All comments saved to 'youtube_all_comments_himachal.csv'.

# %% [markdown]
# # **Jammu and Kashmir**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["0heSaQjHDlI","DdboZTVDedQ","56gutoGso5s"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_jammuandkashmir.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_jammuandkashmir.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: 0heSaQjHDlI
# ✅ Fetched 100 comments so far for 0heSaQjHDlI...
# ✅ Fetched 200 comments so far for 0heSaQjHDlI...
# ✅ Fetched 300 comments so far for 0heSaQjHDlI...
# ✅ Fetched 400 comments so far for 0heSaQjHDlI...
# ✅ Fetched 500 comments so far for 0heSaQjHDlI...
# ✅ Fetched 600 comments so far for 0heSaQjHDlI...
# ✅ Fetched 700 comments so far for 0heSaQjHDlI...
# ✅ Fetched 800 comments so far for 0heSaQjHDlI...
# ✅ Fetched 900 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1000 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1100 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1200 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1300 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1400 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1500 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1600 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1700 comments so far for 0heSaQjHDlI...
# ✅ Fetched 1800 comments so far for 0heSaQjHDlI...
# ...

# %% [markdown]
# # **Madhya Pradesh**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["3tnxS9mcK9g","7e8YxRMavkU","OJbjVGHdPdw","7e8YxRMavkU&t"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_madhyapradesh.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_madhyapradesh.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: 3tnxS9mcK9g
# ✅ Fetched 100 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 200 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 300 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 400 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 500 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 600 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 700 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 800 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 900 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1000 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1100 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1200 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1300 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1400 comments so far for 3tnxS9mcK9g...
# ✅ Fetched 1500 comments so far for 3tnxS9mcK9g...
# ✅ Successfully fetched 1548 total comments for 3tnxS9mcK9g
# 🚀 Fetching comments for video: 7e8YxRMavkU
# ✅ Fetched 100 comments so far for 7e8YxRMavkU...
# ...

# %% [markdown]
# # **KARNATAKA**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["y3g5FQbGG8Q","2nwDMR8MOJ0","fIWoeRIX7bE"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_karnataka.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_karnataka.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: y3g5FQbGG8Q
# ✅ Fetched 100 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 200 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 300 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 400 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 500 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 600 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 700 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 800 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 900 comments so far for y3g5FQbGG8Q...
# ✅ Fetched 1000 comments so far for y3g5FQbGG8Q...
# ✅ Successfully fetched 1068 total comments for y3g5FQbGG8Q
# 🚀 Fetching comments for video: 2nwDMR8MOJ0
# ✅ Fetched 100 comments so far for 2nwDMR8MOJ0...
# ✅ Fetched 200 comments so far for 2nwDMR8MOJ0...
# ✅ Fetched 300 comments so far for 2nwDMR8MOJ0...
# ✅ Fetched 400 comments so far for 2nwDMR8MOJ0...
# ✅ Fetched 500 comments so far for 2nwDMR8MOJ0...
# ✅ Fetched 600 comments so far for 2nwDMR8MOJ0...
# ...

# %% [markdown]
# # **KERALA**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["wb4FuLi5PE8","ynSj5ykwOfA","SlZVaC2ivGA&"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_kerala.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_kerala.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: wb4FuLi5PE8
# ✅ Fetched 100 comments so far for wb4FuLi5PE8...
# ✅ Fetched 200 comments so far for wb4FuLi5PE8...
# ✅ Fetched 300 comments so far for wb4FuLi5PE8...
# ✅ Fetched 400 comments so far for wb4FuLi5PE8...
# ✅ Fetched 500 comments so far for wb4FuLi5PE8...
# ✅ Fetched 600 comments so far for wb4FuLi5PE8...
# ✅ Fetched 700 comments so far for wb4FuLi5PE8...
# ✅ Fetched 800 comments so far for wb4FuLi5PE8...
# ✅ Fetched 900 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1000 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1100 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1200 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1300 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1400 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1500 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1600 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1700 comments so far for wb4FuLi5PE8...
# ✅ Fetched 1800 comments so far for wb4FuLi5PE8...
# ...

# %% [markdown]
# # **Tamil Nadu**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["jXs3wPr6aoI","eqixx8dTkJY&t","dDBK1FvC3TQ"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_tamilnadu.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_tamilnadu.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: jXs3wPr6aoI
# ✅ Fetched 100 comments so far for jXs3wPr6aoI...
# ✅ Fetched 200 comments so far for jXs3wPr6aoI...
# ✅ Fetched 300 comments so far for jXs3wPr6aoI...
# ✅ Fetched 400 comments so far for jXs3wPr6aoI...
# ✅ Fetched 500 comments so far for jXs3wPr6aoI...
# ✅ Fetched 600 comments so far for jXs3wPr6aoI...
# ✅ Fetched 700 comments so far for jXs3wPr6aoI...
# ✅ Fetched 800 comments so far for jXs3wPr6aoI...
# ✅ Fetched 900 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1000 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1100 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1200 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1300 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1400 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1500 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1600 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1700 comments so far for jXs3wPr6aoI...
# ✅ Fetched 1800 comments so far for jXs3wPr6aoI...
# ...

# %% [markdown]
# # **Andhra Pradesh**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = [""]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_andhrapradesh.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_andhrapradesh.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video:
# ❌ Error fetching comments for : <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=&textFormat=plainText&maxResults=100&key=AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# ✅ Successfully fetched 0 total comments for
# ❌ No comments were retrieved. Check API settings and video IDs.

# %% [markdown]
# # **Telanagana**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["zSwnIePpAeo","duI-NXHdbt0","DWTv1lO_fHk"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_telangana.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_telangana.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: zSwnIePpAeo
# ✅ Fetched 100 comments so far for zSwnIePpAeo...
# ✅ Fetched 200 comments so far for zSwnIePpAeo...
# ✅ Fetched 300 comments so far for zSwnIePpAeo...
# ✅ Fetched 400 comments so far for zSwnIePpAeo...
# ✅ Successfully fetched 446 total comments for zSwnIePpAeo
# 🚀 Fetching comments for video: duI-NXHdbt0
# ✅ Fetched 100 comments so far for duI-NXHdbt0...
# ✅ Fetched 200 comments so far for duI-NXHdbt0...
# ✅ Fetched 300 comments so far for duI-NXHdbt0...
# ✅ Fetched 400 comments so far for duI-NXHdbt0...
# ✅ Fetched 500 comments so far for duI-NXHdbt0...
# ✅ Fetched 600 comments so far for duI-NXHdbt0...
# ✅ Successfully fetched 699 total comments for duI-NXHdbt0
# 🚀 Fetching comments for video: DWTv1lO_fHk
# ✅ Successfully fetched 26 total comments for DWTv1lO_fHk
# ✅ All comments saved to 'youtube_all_comments_telangana.csv'.

# %% [markdown]
# # **Haryana**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["YE9vQidBIZk","f1hppCCt0Mg","P-vp2FR_7Mo","DYSiiNBdTWo","iYYrLIKo9ig"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_haryana.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_haryana.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: YE9vQidBIZk
# ✅ Fetched 100 comments so far for YE9vQidBIZk...
# ✅ Fetched 200 comments so far for YE9vQidBIZk...
# ✅ Fetched 300 comments so far for YE9vQidBIZk...
# ✅ Fetched 400 comments so far for YE9vQidBIZk...
# ✅ Fetched 500 comments so far for YE9vQidBIZk...
# ✅ Fetched 600 comments so far for YE9vQidBIZk...
# ✅ Fetched 700 comments so far for YE9vQidBIZk...
# ✅ Fetched 800 comments so far for YE9vQidBIZk...
# ✅ Fetched 900 comments so far for YE9vQidBIZk...
# ✅ Fetched 1000 comments so far for YE9vQidBIZk...
# ✅ Fetched 1100 comments so far for YE9vQidBIZk...
# ✅ Successfully fetched 1117 total comments for YE9vQidBIZk
# 🚀 Fetching comments for video: f1hppCCt0Mg
# ✅ Fetched 100 comments so far for f1hppCCt0Mg...
# ✅ Fetched 200 comments so far for f1hppCCt0Mg...
# ✅ Fetched 300 comments so far for f1hppCCt0Mg...
# ✅ Fetched 400 comments so far for f1hppCCt0Mg...
# ✅ Fetched 500 comments so far for f1hppCCt0Mg...
# ...

# %% [markdown]
# # **Goa**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["kUMGx48VCWk","RLvEPd-z_G4","6B0T15hlOnk"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_goa.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_goa.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: kUMGx48VCWk
# ✅ Successfully fetched 26 total comments for kUMGx48VCWk
# 🚀 Fetching comments for video: RLvEPd-z_G4
# ✅ Fetched 100 comments so far for RLvEPd-z_G4...
# ✅ Fetched 200 comments so far for RLvEPd-z_G4...
# ✅ Fetched 300 comments so far for RLvEPd-z_G4...
# ✅ Successfully fetched 392 total comments for RLvEPd-z_G4
# 🚀 Fetching comments for video: 6B0T15hlOnk
# ✅ Fetched 100 comments so far for 6B0T15hlOnk...
# ✅ Fetched 200 comments so far for 6B0T15hlOnk...
# ✅ Fetched 300 comments so far for 6B0T15hlOnk...
# ✅ Fetched 400 comments so far for 6B0T15hlOnk...
# ✅ Successfully fetched 403 total comments for 6B0T15hlOnk
# ✅ All comments saved to 'youtube_all_comments_goa.csv'.

# %% [markdown]
# # **North-East**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["ziIEdwVSbC4","_FD8C1J8N_A","XXwUnOiOw5M","JuwcKZghg8Y","RGgfpiSxw70","gaaBJlVWFhg&t","DuoAMMn95M4","QaXiYI52qaw","j5x10IMuvxQ","RGxmZ4iWgLg"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_northeast.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_northeast.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: ziIEdwVSbC4
# ✅ Fetched 100 comments so far for ziIEdwVSbC4...
# ✅ Fetched 200 comments so far for ziIEdwVSbC4...
# ✅ Fetched 300 comments so far for ziIEdwVSbC4...
# ✅ Fetched 400 comments so far for ziIEdwVSbC4...
# ✅ Fetched 500 comments so far for ziIEdwVSbC4...
# ✅ Fetched 600 comments so far for ziIEdwVSbC4...
# ✅ Fetched 700 comments so far for ziIEdwVSbC4...
# ✅ Fetched 800 comments so far for ziIEdwVSbC4...
# ✅ Fetched 900 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1000 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1100 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1200 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1300 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1400 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1500 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1600 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1700 comments so far for ziIEdwVSbC4...
# ✅ Fetched 1800 comments so far for ziIEdwVSbC4...
# ...

# %% [markdown]
# # **South and North India**

# %%
# YouTube API Key (Replace with your actual API key)
API_KEY = "AIzaSyCXk7kNmpTMqTLJ3XWk-627S_7v5rNwmaQ"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Function to fetch ALL comments from a video
def get_all_youtube_comments(video_id):
    comments = []
    next_page_token = None

    while True:  # Keep fetching until there are no more pages
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                textFormat="plainText",
                maxResults=100,  # Fetch max comments per request
                pageToken=next_page_token  # Go to next page if available
            )
            response = request.execute()

            if "items" not in response:
                print(f"❌ No comments found for video: {video_id}")
                return []

            for item in response["items"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append([
                    video_id,
                    comment["authorDisplayName"],
                    comment["textDisplay"],
                    comment["likeCount"],
                    comment["publishedAt"]
                ])

            # Check if there's another page of comments
            next_page_token = response.get("nextPageToken")

            if not next_page_token:  # If no more pages, break loop
                break

            print(f"✅ Fetched {len(comments)} comments so far for {video_id}...")

            # Sleep to avoid API rate limits
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error fetching comments for {video_id}: {e}")
            break  # Stop loop if API fails

    print(f"✅ Successfully fetched {len(comments)} total comments for {video_id}")
    return comments

# ✅ List of YouTube Video IDs
video_ids = ["emasPc1adSM","VN07uNnavOQ","8uf-ZfSoOgM","CmtMeqHcoGg","qMEC7OvDF1Q","Qkva8Oyx3o8","2SsWJZxXNSU","JCEc-qY8EMY","lguUra-8QI&t=62s","03sLvRmg1KY","C5g5sBGbKgY"]

# Fetch comments for multiple videos
all_comments = []
for video_id in video_ids:
    print(f"🚀 Fetching comments for video: {video_id}")
    comments_data = get_all_youtube_comments(video_id)
    all_comments.extend(comments_data)

# Save to CSV if comments were extracted
if len(all_comments) > 0:
    df_all_comments = pd.DataFrame(all_comments, columns=["Video_ID", "Author", "Comment", "Likes", "Published"])
    df_all_comments.to_csv("youtube_all_comments_southandnorth.csv", index=False)
    print("✅ All comments saved to 'youtube_all_comments_southandnorth.csv'.")
else:
    print("❌ No comments were retrieved. Check API settings and video IDs.")
# Out:
# 🚀 Fetching comments for video: emasPc1adSM
# ✅ Fetched 100 comments so far for emasPc1adSM...
# ✅ Fetched 200 comments so far for emasPc1adSM...
# ✅ Fetched 300 comments so far for emasPc1adSM...
# ✅ Fetched 400 comments so far for emasPc1adSM...
# ✅ Fetched 500 comments so far for emasPc1adSM...
# ✅ Fetched 600 comments so far for emasPc1adSM...
# ✅ Fetched 700 comments so far for emasPc1adSM...
# ✅ Successfully fetched 777 total comments for emasPc1adSM
# 🚀 Fetching comments for video: VN07uNnavOQ
# ✅ Fetched 100 comments so far for VN07uNnavOQ...
# ✅ Fetched 200 comments so far for VN07uNnavOQ...
# ✅ Fetched 300 comments so far for VN07uNnavOQ...
# ✅ Fetched 400 comments so far for VN07uNnavOQ...
# ✅ Fetched 500 comments so far for VN07uNnavOQ...
# ✅ Fetched 600 comments so far for VN07uNnavOQ...
# ✅ Fetched 700 comments so far for VN07uNnavOQ...
# ✅ Successfully fetched 767 total comments for VN07uNnavOQ
# 🚀 Fetching comments for video: 8uf-ZfSoOgM
# ...
